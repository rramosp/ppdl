# %%
# init repo notebook
# !git clone git@github.com-juselara1:rramosp/ppdl.dev.git
# !mv ppdl.dev/content/init.py ppdl.dev/content/local .

# %% [markdown]
# # 2. Montecarlo and expectations
#
# - explain montecarlo
# - maybe do hipothesis testing with montecarlo and sampling
# - explain expectations
# - explain how to compute integrals (and expectations) with montecarlo
