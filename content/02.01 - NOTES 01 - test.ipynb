# %%
# init repo notebook
# !git clone git@github.com-juselara1:rramosp/ppdl.dev.git
# !mv ppdl.dev/content/init.py ppdl.dev/content/local .

# %% [markdown]
# # test notes
# with techer and keep output

# %%
# this cell shows output (in text notebook??)
print("hola")

# %%
print("adios")
