# %%
# init repo notebook
# !git clone git@github.com-juselara1:rramosp/ppdl.dev.git
# !mv ppdl.dev/content/init.py ppdl.dev/content/local .

# %% [markdown]
# # 3. Data and models
#
# what does it mean to have a probability of data conditioned on model parameters and the other way around
